# %%
from pandas_datareader import data

# %%
gol_df = data.DataReader(name="GOLL4.SA", data_source="yahoo", start="2015-01-01")

# %%
gol_df
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2015-01-02  15.200000  14.610000  14.970000  14.990000   901900.0  14.990000
# 2015-01-05  15.010000  14.410000  14.900000  14.850000  1272500.0  14.850000
# 2015-01-06  15.210000  14.650000  14.750000  15.210000  2183500.0  15.210000
# 2015-01-07  15.330000  14.550000  15.150000  14.550000  1846900.0  14.550000
# 2015-01-08  14.650000  14.200000  14.410000  14.270000  1569500.0  14.270000
# ...               ...        ...        ...        ...        ...        ...
# 2021-02-10  25.120001  24.020000  25.000000  24.260000  5349200.0  24.260000
# 2021-02-11  24.920000  23.930000  24.430000  24.110001  6585300.0  24.110001
# 2021-02-12  24.350000  23.540001  23.700001  24.139999  4655400.0  24.139999
# 2021-02-18  24.350000  23.430000  24.200001  23.570000  4715100.0  23.570000
# 2021-02-19  24.139999  23.410000  23.520000  23.790001  4628400.0  23.790001
#
# [1519 rows x 6 columns]

# %%
gol_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1519 entries, 2015-01-02 to 2021-02-19
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       1519 non-null   float64
#  1   Low        1519 non-null   float64
#  2   Open       1519 non-null   float64
#  3   Close      1519 non-null   float64
#  4   Volume     1519 non-null   float64
#  5   Adj Close  1519 non-null   float64
# dtypes: float64(6)
# memory usage: 83.1 KB

# %%
gol_df[gol_df['Close'] >= 43.79]
# Out:
#                  High    Low   Open      Close     Volume  Adj Close
# Date
# 2019-08-01  44.619999  41.25  41.25  43.790001  6664200.0  43.790001

# %%
gol_df[gol_df['Close'] <= 1.16]
# Out:
#             High   Low  Open  Close     Volume  Adj Close
# Date
# 2016-01-22  1.26  1.14   1.2   1.16  3830600.0       1.16

# %%
acoes = ["GOLL4.SA", "CVCB3.SA", "WEGE3.SA", "MGLU3.SA", "TOTS3.SA", "BOVA11.SA"]

# %%
import pandas as pd

# %%
acoes_df = pd.DataFrame()

# %%
for acao in acoes:
    acoes_df[acao] = data.DataReader(name=acao, data_source="yahoo", start="2015-01-01")['Close']

# %%
acoes_df
# Out:
#              GOLL4.SA   CVCB3.SA   WEGE3.SA   MGLU3.SA   TOTS3.SA   BOVA11.SA
# Date
# 2015-01-02  14.990000  15.200000  11.846153   0.232812  11.910702   47.259998
# 2015-01-05  14.850000  15.000000  11.926923   0.237187  11.544731   46.320000
# 2015-01-06  15.210000  14.800000  11.750000   0.234062  10.822770   46.580002
# 2015-01-07  14.550000  14.670000  11.615384   0.241875  10.746248   48.150002
# 2015-01-08  14.270000  14.150000  11.811538   0.240000  10.995774   48.509998
# ...               ...        ...        ...        ...        ...         ...
# 2021-02-10  24.260000  19.230000  86.029999  25.299999  31.410000  113.919998
# 2021-02-11  24.110001  18.850000  87.000000  25.650000  33.849998  114.900002
# 2021-02-12  24.139999  19.900000  86.669998  25.910000  34.639999  115.050003
# 2021-02-18  23.570000  19.000000  83.379997  25.040001  33.900002         NaN
# 2021-02-19  23.790001  18.639999  83.239998  24.940001  34.730000  113.820000
#
# [1519 rows x 6 columns]

# %%
acoes_df.isnull().sum()
# Out:
# GOLL4.SA     0
# CVCB3.SA     0
# WEGE3.SA     0
# MGLU3.SA     0
# TOTS3.SA     0
# BOVA11.SA    1
# dtype: int64

# %%
acoes_df.dropna(inplace=True)

# %%
acoes_df.isnull().sum()
# Out:
# GOLL4.SA     0
# CVCB3.SA     0
# WEGE3.SA     0
# MGLU3.SA     0
# TOTS3.SA     0
# BOVA11.SA    0
# dtype: int64

# %%
acoes_df.describe()
# Out:
#           GOLL4.SA     CVCB3.SA     WEGE3.SA     MGLU3.SA     TOTS3.SA  \
# count  1518.000000  1518.000000  1518.000000  1518.000000  1518.000000
# mean     14.995224    32.132877    23.694116     5.575661    13.760695
# std      10.192107    16.075781    18.678665     7.245122     6.145542
# min       1.160000     6.106568     9.884615     0.030585     7.156402
# 25%       6.957500    18.027500    12.742307     0.218750     9.847955
# 50%      12.465000    26.420000    17.169230     2.485000    10.776191
# 75%      21.242500    46.997500    22.704999     8.062500    16.073332
# max      43.790001    64.800003    92.209999    27.450001    34.730000
#
#          BOVA11.SA
# count  1518.000000
# mean     73.562082
# std      21.087091
# min      36.450001
# 25%      55.054999
# 50%      72.415001
# 75%      92.479998
# max     120.400002

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,50))

for i in np.arange(1, len(acoes_df.columns)):
    plt.subplot(7, 1, i + 1)
    sns.histplot(acoes_df[acoes_df.columns[i]], kde=True)
    plt.title(acoes_df.columns[i])

# %%
plt.figure(figsize=(10,50))

for i in np.arange(1, len(acoes_df.columns)):
    plt.subplot(7, 1, i + 1)
    sns.boxplot(x = acoes_df[acoes_df.columns[i]])
    plt.title(acoes_df.columns[i])

# %%
acoes_df['GOLL4.SA'].describe()
# Out:
# count    1518.000000
# mean       14.995224
# std        10.192107
# min         1.160000
# 25%         6.957500
# 50%        12.465000
# 75%        21.242500
# max        43.790001
# Name: GOLL4.SA, dtype: float64

# %%
acoes_df.plot(figsize=(15,7), title="Histórico do Preço das Ações")
# Out:
# <AxesSubplot:title={'center':'Histórico do Preço das Ações'}, xlabel='Date'>

# %%
acoes_df_norm = acoes_df.copy()

for i in acoes_df_norm.columns:
    acoes_df_norm[i] = acoes_df_norm[i] / acoes_df_norm[i][0]

# %%
acoes_df_norm
# Out:
#             GOLL4.SA  CVCB3.SA  WEGE3.SA    MGLU3.SA  TOTS3.SA  BOVA11.SA
# Date
# 2015-01-02  1.000000  1.000000  1.000000    1.000000  1.000000   1.000000
# 2015-01-05  0.990660  0.986842  1.006818    1.018792  0.969274   0.980110
# 2015-01-06  1.014676  0.973684  0.991883    1.005369  0.908659   0.985612
# 2015-01-07  0.970647  0.965132  0.980519    1.038928  0.902235   1.018832
# 2015-01-08  0.951968  0.930921  0.997078    1.030875  0.923184   1.026449
# ...              ...       ...       ...         ...       ...        ...
# 2021-02-09  1.667779  1.294079  7.176169  112.708965  2.588429   2.431443
# 2021-02-10  1.618412  1.265132  7.262273  108.671370  2.637124   2.410495
# 2021-02-11  1.608406  1.240132  7.344156  110.174731  2.841982   2.431232
# 2021-02-12  1.610407  1.309211  7.316299  111.291512  2.908309   2.434406
# 2021-02-19  1.587058  1.226316  7.026753  107.125064  2.915865   2.408379
#
# [1518 rows x 6 columns]

# %%
acoes_df_norm.plot(figsize=(15,7), title="Histórico do Preço das Ações Normalizado")
# Out:
# <AxesSubplot:title={'center':'Histórico do Preço das Ações Normalizado'}, xlabel='Date'>

# %%
import plotly.express as px

# %%
figure = px.line(title="Histórico do Preço das Ações")
for i in acoes_df.columns:
    figure.add_scatter(x=acoes_df.index, y=acoes_df[i], name=i)

figure.show()
# Out:
# <div>                            <div id="b4c07c49-c1ec-40e4-8391-547df73fc255" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4c07c49-c1ec-40e4-8391-547df73fc255")) {                    Plotly.newPlot(                        "b4c07c49-c1ec-40e4-8391-547df73fc255",                        [{"name": "GOLL4.SA", "type": "scatter", "x": ["2015-01-02T00:00:00", "2015-01-05T00:00:00", "2015-01-06T00:00:00", "2015-01-07T00:00:00", "2015-01-08T00:00:00", "2015-01-09T00:00:00", "2015-01-12T00:00:00", "2015-01-13T00:00:00", "2015-01-14T00:00:00", "2015-01-15T00:00:00", "2015-01-16T00:00:00", "2015-01-19T00:00:00", "2015-01-20T00:00:00", "2015-01-21T00:00:00", "2015-01-22T00:00:00", "2015-01-23T00:00:00", "2015-01-26T00:00:00", "2015-01-27T00:00:00", "2015-0
# ...

# %%
figure = px.line(title="Histórico do Preço das Ações Normalizado")
for i in acoes_df_norm.columns:
    figure.add_scatter(x=acoes_df_norm.index, y=acoes_df_norm[i], name=i)

figure.show()
# Out:
# <div>                            <div id="9a080691-137f-419a-b8d5-db3570bc78dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a080691-137f-419a-b8d5-db3570bc78dc")) {                    Plotly.newPlot(                        "9a080691-137f-419a-b8d5-db3570bc78dc",                        [{"name": "GOLL4.SA", "type": "scatter", "x": ["2015-01-02T00:00:00", "2015-01-05T00:00:00", "2015-01-06T00:00:00", "2015-01-07T00:00:00", "2015-01-08T00:00:00", "2015-01-09T00:00:00", "2015-01-12T00:00:00", "2015-01-13T00:00:00", "2015-01-14T00:00:00", "2015-01-15T00:00:00", "2015-01-16T00:00:00", "2015-01-19T00:00:00", "2015-01-20T00:00:00", "2015-01-21T00:00:00", "2015-01-22T00:00:00", "2015-01-23T00:00:00", "2015-01-26T00:00:00", "2015-01-27T00:00:00", "2015-0
# ...
